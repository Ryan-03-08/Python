# %%
#Theory Questions
"""
1. What is NumPy, and why is it widely used in Python?

NumPy is a Python library used for numerical and scientific computing.
It is widely used because it provides fast, memory-efficient array operations, mathematical functions, and support for multidimensional data.

2. How does broadcasting work in NumPy?

Broadcasting allows NumPy to perform operations on arrays of different shapes without explicit looping.
Smaller arrays are automatically expanded to match the shape of larger ones.

3. What is a Pandas DataFrame?

A Pandas DataFrame is a two-dimensional, labeled data structure similar to a table or spreadsheet.
It allows easy data manipulation, filtering, and analysis.

4. Explain the use of the groupby() method in Pandas

The groupby() method is used to group data based on one or more columns.
It enables aggregation operations like sum, mean, count, and max on grouped data.

5. Why is Seaborn preferred for statistical visualizations?

Seaborn provides high-level, aesthetically pleasing plots with minimal code.
It integrates well with Pandas and is ideal for statistical data analysis.

6. What are the differences between NumPy arrays and Python lists?

NumPy arrays are homogeneous and faster for numerical operations.
Python lists are heterogeneous and more flexible but slower for large computations.

7. What is a heatmap, and when should it be used?

A heatmap is a graphical representation of data where values are shown using color intensity.
It is useful for visualizing correlations, patterns, and matrices.

8. What does the term “vectorized operation” mean in NumPy?

Vectorized operations apply computations to entire arrays at once instead of using loops.
This improves performance and code readability.

9. How does Matplotlib differ from Plotly?

Matplotlib produces static plots and offers fine-grained control.
Plotly creates interactive, web-based visualizations.

10. What is the significance of hierarchical indexing in Pandas?

Hierarchical indexing (MultiIndex) allows multiple levels of indexing on rows or columns.
It helps represent higher-dimensional data in a two-dimensional structure.

11. What is the role of Seaborn’s pairplot() function?

pairplot() visualizes pairwise relationships between numerical variables.
It is useful for exploratory data analysis.

12. What is the purpose of the describe() function in Pandas?

The describe() function provides summary statistics like count, mean, standard deviation, min, and max.
It helps quickly understand the distribution of data.

13. Why is handling missing data important in Pandas?

Missing data can lead to incorrect analysis and biased results.
Pandas provides tools like fillna() and dropna() to handle missing values.

14. What are the benefits of using Plotly for data visualization?

Plotly supports interactive charts, zooming, and tooltips.
It is ideal for dashboards and web-based visualizations.

15. How does NumPy handle multidimensional arrays?

NumPy uses the ndarray object to store multidimensional arrays.
It supports efficient indexing, slicing, and mathematical operations.

16. What is the role of Bokeh in data visualization?

Bokeh is used for creating interactive visualizations for web browsers.
It allows real-time updates and interactive dashboards.

17. Explain the difference between apply() and map() in Pandas

map() works on Series elements one by one.
apply() can operate on rows or columns of a DataFrame.

18. What are some advanced features of NumPy?

Advanced features include broadcasting, vectorization, linear algebra, FFT, and random number generation.
These make NumPy powerful for scientific computing.

19. How does Pandas simplify time series analysis?

Pandas provides date-time indexing, resampling, shifting, and rolling operations.
These features make time-based data analysis easier.

20. What is the role of a pivot table in Pandas?

A pivot table summarizes data by aggregating values across categories.
It helps in analyzing large datasets efficiently.

21. Why is NumPy’s array slicing faster than Python’s list slicing?

NumPy slicing returns a view instead of a copy, reducing memory overhead.
This makes operations significantly faster.

22. What are some common use cases for Seaborn?

Seaborn is commonly used for statistical analysis, correlation plots, distribution plots, and regression visualization.
It is popular in data science and exploratory analysis.
"""

# %%
##Practical Questions

#Q1. How do you create a 2D NumPy array and calculate the sum of each row
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])
row_sum = arr.sum(axis=1)
print(row_sum)


#Q2. Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd

df = pd.DataFrame({
    "marks": [70, 80, 90, 85]
})
print(df["marks"].mean())


#Q3. Create a scatter plot using Matplotlib
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.scatter(x, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter Plot")
plt.show()


#Q4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap
import seaborn as sns
import pandas as pd

data = pd.DataFrame({
    "A": [1, 2, 3, 4],
    "B": [2, 4, 6, 8],
    "C": [5, 6, 7, 8]
})

corr = data.corr()
sns.heatmap(corr, annot=True)
plt.show()


#Q5. Generate a bar plot using Plotly
import plotly.express as px

df = pd.DataFrame({
    "Fruits": ["Apple", "Banana", "Orange"],
    "Quantity": [10, 15, 7]
})

fig = px.bar(df, x="Fruits", y="Quantity", title="Bar Plot")
fig.show()


#Q6. Create a DataFrame and add a new column based on an existing column
df = pd.DataFrame({
    "Salary": [30000, 40000, 50000]
})

df["Bonus"] = df["Salary"] * 0.10
print(df)


#Q7. Write a program to perform element-wise multiplication of two NumPy arrays
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

result = a * b
print(result)


#Q8. Create a line plot with multiple lines using Matplotlib
x = [1, 2, 3, 4]

y1 = [10, 20, 30, 40]
y2 = [5, 15, 25, 35]

plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")
plt.legend()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple Line Plot")
plt.show()


#Q9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold
df = pd.DataFrame({
    "Score": [45, 67, 89, 34, 90]
})

filtered_df = df[df["Score"] > 60]
print(filtered_df)


#Q10. Create a histogram using Seaborn to visualize a distribution
data = [10, 20, 20, 30, 30, 30, 40]

sns.histplot(data, bins=5)
plt.title("Histogram")
plt.show()


#Q11. Perform matrix multiplication using NumPy
mat1 = np.array([[1, 2],
                 [3, 4]])
mat2 = np.array([[5, 6],
                 [7, 8]])

product = np.dot(mat1, mat2)
print(product)


#Q12. Use Pandas to load a CSV file and display its first 5 rows
df = pd.read_csv("data.csv")
print(df.head())


#Q13. Create a 3D scatter plot using Plotly
import plotly.express as px

df = pd.DataFrame({
    "x": [1, 2, 3, 4],
    "y": [10, 20, 30, 40],
    "z": [5, 15, 25, 35]
})

fig = px.scatter_3d(df, x="x", y="y", z="z", title="3D Scatter Plot")
fig.show()
# Out:
# [ 6 15]
# 81.25
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
