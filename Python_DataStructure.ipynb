# %%
#Theory Questions

"""Q1. What are data structures, and why are they important?
-Data structures are ways of organizing and storing data so it can be accessed and modified efficiently.
They are important because they improve performance, memory usage, and code clarity, especially when handling large amounts of data.

Q2. Explain the difference between mutable and immutable data types with examples
-Mutable data types can be changed after creation, while immutable data types cannot.
For example, lists are mutable ([1,2,3] can be modified), whereas strings and tuples are immutable ("abc" and (1,2,3) cannot be changed).

Q3. What are the main differences between lists and tuples in Python?
-Lists are mutable and written using square brackets [], while tuples are immutable and written using parentheses ().
Lists are suitable for dynamic data, whereas tuples are used for fixed, constant data.

Q4. Describe how dictionaries store data
-Dictionaries store data in key–value pairs, where each key is unique and maps to a specific value.
Internally, dictionaries use a hash table for fast data access.

Q5. Why might you use a set instead of a list in Python?
-Sets automatically remove duplicate elements and allow faster membership testing.
They are useful when uniqueness and performance are more important than order.

Q6. What is a string in Python, and how is it different from a list?
-A string is an immutable sequence of characters, while a list is a mutable sequence of elements.
Unlike lists, individual characters in a string cannot be modified.

Q7. How do tuples ensure data integrity in Python?
-Tuples are immutable, meaning their contents cannot be altered once created.
This prevents accidental changes and helps maintain data consistency.

Q8. What is a hash table, and how does it relate to dictionaries in Python?
-A hash table is a data structure that stores data using a hash function for fast access.
Python dictionaries are implemented using hash tables, enabling constant-time average lookups.

Q9. Can lists contain different data types in Python?
-Yes, lists can store multiple data types such as integers, strings, floats, and even other lists.
Example: [1, "Python", 3.5, [2,3]].

Q10. Explain why strings are immutable in Python
-Strings are immutable to improve performance, memory efficiency, and security.
Once created, a string cannot be changed, so any modification creates a new string.

Q11. What advantages do dictionaries offer over lists for certain tasks?
-Dictionaries provide faster data retrieval using keys instead of index searching.
They are ideal when data needs to be accessed using unique identifiers.

Q12. Describe a scenario where using a tuple would be preferable over a list
-Tuples are preferred when storing constant data such as coordinates (x, y) or fixed configuration values.
Their immutability prevents accidental modification.

13. How do sets handle duplicate values in Python?
-Sets automatically eliminate duplicate values.
If duplicate elements are added, only one instance is stored.

14. How does the in keyword work differently for lists and dictionaries?
-In a list, in checks for the presence of a value.
In a dictionary, in checks only for the presence of a key, not a value.

Q15. Can you modify the elements of a tuple? Explain why or why not
-No, tuple elements cannot be modified because tuples are immutable.
This design ensures data safety and integrity.

Q16. What is a nested dictionary, and give an example of its use case
-A nested dictionary is a dictionary that contains another dictionary as a value.
It is commonly used to store structured data like student records or JSON data.

Q17. Describe the time complexity of accessing elements in a dictionary
-Accessing elements in a dictionary has an average time complexity of O(1).
This is due to its hash table implementation.

Q18. In what situations are lists preferred over dictionaries?
-Lists are preferred when order matters and elements are accessed by index.
They are ideal for sequential data and repeated iteration.

Q19. Why are dictionaries considered unordered, and how does that affect data retrieval?
-Dictionaries are conceptually unordered because data is accessed by keys, not position.
This means retrieval is fast but not based on index order.

Q20. Explain the difference between a list and a dictionary in terms of data retrieval
-Lists retrieve data using index positions, which may require searching.
Dictionaries retrieve data using keys, allowing faster and more efficient access."""

# %%
#Coding Questions
#Q1. Write a code to create a string with your name and print it
name = "Ryan Biswas"
print(name)

#Q2. Write a code to find the length of the string "Hello World"
text = "Hello World"
print(len(text))

#Q3. Write a code to slice the first 3 characters from the string "Python Programming"
text = "Python Programming"
print(text[:3])

#Q4. Write a code to convert the string "hello" to uppercase
text = "hello"
print(text.upper())

#Q5. Write a code to replace the word "apple" with "orange" in the string "I like apple"
text = "I like apple"
print(text.replace("apple", "orange"))

#Q6. Write a code to create a list with numbers 1 to 5 and print it
numbers = [1, 2, 3, 4, 5]
print(numbers)

#Q7. Write a code to append the number 10 to the list [1, 2, 3, 4]
lst = [1, 2, 3, 4]
lst.append(10)
print(lst)

#Q8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
lst = [1, 2, 3, 4, 5]
lst.remove(3)
print(lst)

#Q9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']
lst = ['a', 'b', 'c', 'd']
print(lst[1])

#Q10. Write a code to reverse the list [10, 20, 30, 40, 50]
lst = [10, 20, 30, 40, 50]
lst.reverse()
print(lst)

#Q11. Write a code to create a tuple with the elements 100, 200, 300 and print it
t = (100, 200, 300)
print(t)

#Q12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])

#Q13. Write a code to find the minimum number in the tuple (10, 20, 5, 15)
t = (10, 20, 5, 15)
print(min(t))

#Q14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
animals = ('dog', 'cat', 'rabbit')
print(animals.index("cat"))

#Q15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it
fruits = ('apple', 'banana', 'mango')
print("kiwi" in fruits)

#Q16. Write a code to create a set with the elements 'a', 'b', 'c' and print it
s = {'a', 'b', 'c'}
print(s)

#Q17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}
s = {1, 2, 3, 4, 5}
s.clear()
print(s)

#Q18. Write a code to remove the element 4 from the set {1, 2, 3, 4}
s = {1, 2, 3, 4}
s.remove(4)
print(s)

#Q19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}
set1 = {1, 2, 3}
set2 = {3, 4, 5}
print(set1.union(set2))

#Q20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}
set1 = {1, 2, 3}
set2 = {2, 3, 4}
print(set1.intersection(set2))

#Q21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it
person = {"name": "John", "age": 25, "city": "New York"}
print(person)

#Q22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}
person = {"name": "John", "age": 25}
person["country"] = "USA"
print(person)

#Q23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
person = {"name": "Alice", "age": 30}
print(person["name"])

#Q24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}
person = {"name": "Bob", "age": 22, "city": "New York"}
person.pop("age")
print(person)

#Q25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}
person = {"name": "Alice", "city": "Paris"}
print("city" in person)

#Q26. Write a code to create a list, a tuple, and a dictionary, and print them all
lst = [1, 2, 3]
tup = (4, 5, 6)
dct = {"a": 10, "b": 20}
print(lst)
print(tup)
print(dct)

#Q27. Write a code to create a list of 5 random numbers between 1 and 100, sort it, and print the result
import random
numbers = [random.randint(1, 100) for _ in range(5)]
numbers.sort()
print(numbers)

#Q28. Write a code to create a list with strings and print the element at the third index
lst = ["apple", "banana", "cherry", "date"]
print(lst[3])

#Q29. Write a code to combine two dictionaries into one and print the result
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}
combined = {**d1, **d2}
print(combined)

#Q30. Write a code to convert a list of strings into a set
lst = ["apple", "banana", "apple", "cherry"]
s = set(lst)
print(s)
# Out:
# Ryan Biswas
# 11
# Pyt
# HELLO
# I like orange
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 10]
# [1, 2, 4, 5]
# b
# [50, 40, 30, 20, 10]
# (100, 200, 300)
# blue
# 5
# 1
# False
# {'a', 'c', 'b'}
# set()
# {1, 2, 3}
# {1, 2, 3, 4, 5}
# {2, 3}
# {'name': 'John', 'age': 25, 'city': 'New York'}
# {'name': 'John', 'age': 25, 'country': 'USA'}
# Alice
# {'name': 'Bob', 'city': 'New York'}
# True
# [1, 2, 3]
# (4, 5, 6)
# {'a': 10, 'b': 20}
# [49, 53, 62, 68, 71]
# date
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'cherry', 'banana', 'apple'}
